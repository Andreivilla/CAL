# %%
import matplotlib.pyplot as plt

# %%
tempos = [0, 1.0000]
fiboN = [0, 46]

# %%
plt.plot(fiboN, tempos)
plt.grid()
plt.title("Iterativo")
plt.xlabel("Número de Fibonacci")
plt.ylabel("Tempo de execução")
plt.savefig("GraficoIterativo", format = "png")
plt.show()
