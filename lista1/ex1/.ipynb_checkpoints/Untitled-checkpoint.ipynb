# %%
import matplotlib.pyplot as plt

# %%
tempos = [0, 1.0000]
fiboN = [0, 46]

# %%
plt.plot(fiboN, tempos)
plt.grid()
plt.title("Recursivo")
plt.xlabel("Numeuro de Fibonacci")
plt.ylabel("Tempo de execução")
plt.savefig("GraficoInterativo", format = "png")
plt.show()
